# %%
import pandas as pd
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('laptops.csv')
df.head(5)
# Out:
#    index   brand                                              Model  Price  \
# 0      1   tecno  Tecno Megabook T1 Laptop (11th Gen Core i3/ 8G...  23990
# 1      2   tecno  Tecno Megabook T1 Laptop (11th Gen Core i7/ 16...  35990
# 2      3      hp  HP Victus 15-fb0157AX Gaming Laptop (AMD Ryzen...  51100
# 3      4    acer  Acer Extensa EX214-53 Laptop (12th Gen Core i5...  39990
# 4      5  lenovo  Lenovo V15 82KDA01BIH Laptop (AMD Ryzen 3 5300...  28580
#
#    Rating processor_brand processor_tier  num_cores  num_threads  ram_memory  \
# 0      63           intel        core i3          2            4           8
# 1      67           intel        core i7          4            8          16
# 2      73             amd        ryzen 5          6           12           8
# 3      62           intel        core i5         12           16           8
# 4      62             amd        ryzen 3          4            8           8
#
# ...

# %%
df = df.set_index('index')

# %%
df.head(5)
# Out:
#         brand                                              Model  Price  \
# index
# 1       tecno  Tecno Megabook T1 Laptop (11th Gen Core i3/ 8G...  23990
# 2       tecno  Tecno Megabook T1 Laptop (11th Gen Core i7/ 16...  35990
# 3          hp  HP Victus 15-fb0157AX Gaming Laptop (AMD Ryzen...  51100
# 4        acer  Acer Extensa EX214-53 Laptop (12th Gen Core i5...  39990
# 5      lenovo  Lenovo V15 82KDA01BIH Laptop (AMD Ryzen 3 5300...  28580
#
#        Rating processor_brand processor_tier  num_cores  num_threads  \
# index
# 1          63           intel        core i3          2            4
# 2          67           intel        core i7          4            8
# 3          73             amd        ryzen 5          6           12
# 4          62           intel        core i5         12           16
# 5          62             amd        ryzen 3          4            8
#
#        ram_memory primary_storage_type  ...  secondary_storage_type  \
# ...

# %%
df.dtypes
# Out:
# brand                          object
# Model                          object
# Price                           int64
# Rating                          int64
# processor_brand                object
# processor_tier                 object
# num_cores                       int64
# num_threads                     int64
# ram_memory                      int64
# primary_storage_type           object
# primary_storage_capacity        int64
# secondary_storage_type         object
# secondary_storage_capacity      int64
# gpu_brand                      object
# gpu_type                       object
# is_touch_screen                  bool
# display_size                  float64
# resolution_width                int64
# resolution_height               int64
# OS                             object
# year_of_warranty               object
# dtype: object

# %%
df.isnull().sum()
# Out:
# brand                         0
# Model                         0
# Price                         0
# Rating                        0
# processor_brand               0
# processor_tier                0
# num_cores                     0
# num_threads                   0
# ram_memory                    0
# primary_storage_type          0
# primary_storage_capacity      0
# secondary_storage_type        0
# secondary_storage_capacity    0
# gpu_brand                     0
# gpu_type                      0
# is_touch_screen               0
# display_size                  0
# resolution_width              0
# resolution_height             0
# OS                            0
# year_of_warranty              0
# dtype: int64

# %%
df.shape
# Out:
# (991, 21)

# %%
df.columns
# Out:
# Index(['brand', 'Model', 'Price', 'Rating', 'processor_brand',
#        'processor_tier', 'num_cores', 'num_threads', 'ram_memory',
#        'primary_storage_type', 'primary_storage_capacity',
#        'secondary_storage_type', 'secondary_storage_capacity', 'gpu_brand',
#        'gpu_type', 'is_touch_screen', 'display_size', 'resolution_width',
#        'resolution_height', 'OS', 'year_of_warranty'],
#       dtype='object')

# %%
df.describe()
# Out:
#                Price      Rating   num_cores  num_threads  ram_memory  \
# count     991.000000  991.000000  991.000000   991.000000  991.000000
# mean    77266.504541   63.931382    8.128153    12.191726   13.047427
# std     57384.910269   10.190575    4.215499     5.585115    5.591188
# min      9800.000000   24.000000    2.000000     0.000000    2.000000
# 25%     43595.000000   58.000000    6.000000     8.000000    8.000000
# 50%     61900.000000   64.000000    8.000000    12.000000   16.000000
# 75%     89245.000000   71.000000   10.000000    16.000000   16.000000
# max    454490.000000   89.000000   24.000000    32.000000   36.000000
#
#        primary_storage_capacity  secondary_storage_capacity  display_size  \
# count                991.000000                  991.000000    991.000000
# mean                 610.938446                    4.004036     15.171241
# std                  266.927666                   33.553936      0.938089
# ...

# %% [markdown]
# # Total number of Laptops

# %%
df['brand'].count()
# Out:
# 991

# %% [markdown]
# # Total number of Brands

# %%
df['brand'].nunique()
# Out:
# 26

# %% [markdown]
# # Total number of Models

# %%
df['Model'].count()
# Out:
# 991

# %% [markdown]
# # Total Models by Brands

# %%
plt.figure(figsize=(10,6))
ax=sns.countplot(x='brand', data=df, palette='magma')
ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right')    
for bars in ax.containers:
    ax.bar_label(bars)
plt.title('Total Models By Brands')  
plt.xlabel('Brands')
plt.ylabel('Total Models')
sns.set_style("whitegrid")
plt.grid(False)
plt.show()

# %% [markdown]
# # Total Models by Primary Storage Capacity

# %%
model_by_prim_sto = df.groupby('primary_storage_capacity')['Model'].count().sort_values(ascending=False)
model_by_prim_sto
# Out:
# primary_storage_capacity
# 512     708
# 1024    208
# 256      45
# 128      11
# 64        9
# 2048      8
# 32        2
# Name: Model, dtype: int64

# %%
sns.barplot(y=model_by_prim_sto.values, x=model_by_prim_sto.index, orient='vertical', palette='rocket')
plt.title('Total Models By Primary Storage Capacity')  
plt.xlabel('Primary Storage Capacity')
plt.ylabel('Total Models')
sns.set_style("whitegrid")
plt.grid(False)
plt.show()

# %% [markdown]
# # Total Models by Primary Storage Type

# %%
model_by_prim_type = df.groupby('primary_storage_type')['Model'].count().sort_values(ascending=False)
model_by_prim_type
# Out:
# primary_storage_type
# SSD    964
# HDD     27
# Name: Model, dtype: int64

# %%
plt.pie(model_by_prim_type .values, labels=model_by_prim_type .index, autopct='%1.1f%%', startangle=140)
plt.title('Distribution of Models by Primary Storage Type')
plt.show()

# %% [markdown]
# # Total Models by Secondary Storage Type

# %%
model_by_seco_type = df.groupby('secondary_storage_type')['Model'].count().sort_values(ascending=False)
model_by_seco_type
# Out:
# secondary_storage_type
# No secondary storage    976
# SSD                      15
# Name: Model, dtype: int64

# %%
plt.pie(model_by_seco_type.values, labels=model_by_seco_type.index, autopct='%1.1f%%', startangle=140)
plt.title('Distribution of Models by Secondary Storage Type')
plt.show()

# %% [markdown]
# # Total Models By Operating System(OS)

# %%
model_by_OS = df.groupby('OS')['Model'].count().sort_values(ascending=False)
model_by_OS
# Out:
# OS
# windows    924
# dos         32
# chrome      16
# mac         15
# other        2
# android      1
# ubuntu       1
# Name: Model, dtype: int64

# %%
barplot = sns.barplot(y=model_by_OS.index, x=model_by_OS.values, orient='horizontal', palette='Greens_d')
plt.bar_label(barplot.containers[0], labels=model_by_OS.values, label_type='edge')
plt.title('Number of Models By OS')
plt.xlabel('Total Models')
plt.ylabel('OS')
plt.grid(False)
plt.show()

# %% [markdown]
# # Total Models By Processor Brand

# %%
model_by_proc_brand = df.groupby('processor_brand')['Model'].count().sort_values(ascending=False)
model_by_proc_brand
# Out:
# processor_brand
# intel    705
# amd      267
# apple     15
# other      4
# Name: Model, dtype: int64

# %%
barplot2=sns.barplot(y=model_by_proc_brand.values, x=model_by_proc_brand.index, orient='vertical', palette='OrRd')
plt.bar_label(barplot2.containers[0], labels=model_by_proc_brand.values, label_type='edge')
plt.title('Total Models By Processor Brand')  
plt.xlabel('Processor Brand')
plt.ylabel('Total Models')
sns.set_style("whitegrid")
plt.grid(False)
plt.show()

# %% [markdown]
# # Total Models By Processor Tier

# %%
model_by_proc_tier = df.groupby('processor_tier')['Model'].count().sort_values(ascending=False)
model_by_proc_tier
# Out:
# processor_tier
# core i5         335
# core i7         159
# ryzen 5         139
# core i3         127
# ryzen 7          77
# celeron          40
# core i9          37
# ryzen 3          31
# other            14
# ryzen 9          12
# m3                8
# m2                6
# core ultra 7      3
# pentium           2
# m1                1
# Name: Model, dtype: int64

# %%
barplot1=sns.barplot(x=model_by_proc_tier.values, y=model_by_proc_tier.index, orient='horizontal', palette='CMRmap')
plt.bar_label(barplot1.containers[0], labels=model_by_proc_tier.values, label_type='edge')
plt.title('Total Models By Processor Tier')  
plt.ylabel('Processor Tier')
plt.xlabel('Total Models')
sns.set_style("whitegrid")
plt.grid(False)
plt.show()

# %% [markdown]
# # Total Model By Touch Screen

# %%
model_by_touch_scr = df.groupby('is_touch_screen')['Model'].count().sort_values(ascending=False)
model_by_touch_scr
# Out:
# is_touch_screen
# False    903
# True      88
# Name: Model, dtype: int64

# %%
plt.pie(model_by_touch_scr.values, labels=model_by_touch_scr.index, autopct='%1.1f%%', startangle=140)
plt.title('Distribution of Models by Touch screen')
plt.show()

# %% [markdown]
# # Total Model By Yearly Warranty

# %%
df.columns
# Out:
# Index(['brand', 'Model', 'Price', 'Rating', 'processor_brand',
#        'processor_tier', 'num_cores', 'num_threads', 'ram_memory',
#        'primary_storage_type', 'primary_storage_capacity',
#        'secondary_storage_type', 'secondary_storage_capacity', 'gpu_brand',
#        'gpu_type', 'is_touch_screen', 'display_size', 'resolution_width',
#        'resolution_height', 'OS', 'year_of_warranty'],
#       dtype='object')

# %%
model_by_warranty = df.groupby('year_of_warranty')['Model'].count().sort_values(ascending=False)
model_by_warranty
# Out:
# year_of_warranty
# 1                 900
# 2                  63
# No information     18
# 3                  10
# Name: Model, dtype: int64

# %%
barplot4=sns.barplot(y=model_by_warranty.values, x=model_by_warranty.index, orient='vertical', palette='GnBu')
plt.bar_label(barplot4.containers[0], labels=model_by_warranty.values, label_type='edge')
plt.title('Total Models By Warranty')  
plt.xlabel('Warranty Years')
plt.ylabel('Total Models')
sns.set_style("whitegrid")
plt.grid(False)
plt.show()

# %%
df.head(5)
# Out:
#         brand                                              Model  Price  \
# index
# 1       tecno  Tecno Megabook T1 Laptop (11th Gen Core i3/ 8G...  23990
# 2       tecno  Tecno Megabook T1 Laptop (11th Gen Core i7/ 16...  35990
# 3          hp  HP Victus 15-fb0157AX Gaming Laptop (AMD Ryzen...  51100
# 4        acer  Acer Extensa EX214-53 Laptop (12th Gen Core i5...  39990
# 5      lenovo  Lenovo V15 82KDA01BIH Laptop (AMD Ryzen 3 5300...  28580
#
#        Rating processor_brand processor_tier  num_cores  num_threads  \
# index
# 1          63           intel        core i3          2            4
# 2          67           intel        core i7          4            8
# 3          73             amd        ryzen 5          6           12
# 4          62           intel        core i5         12           16
# 5          62             amd        ryzen 3          4            8
#
#        ram_memory primary_storage_type  ...  secondary_storage_type  \
# ...

# %% [markdown]
# # Total Models By Resolution

# %%
resolution=df.groupby(['resolution_width', 'resolution_height'])['Model'].count().sort_values(ascending=False)
resolution
# Out:
# resolution_width  resolution_height
# 1920              1080                 648
#                   1200                 128
# 2560              1600                  64
# 1366              768                   52
# 2880              1800                  29
# 2560              1440                  14
# 1080              1920                   7
# 2880              1620                   6
# 3200              1800                   5
# 3456              2234                   4
# 3024              1964                   4
# 3000              2000                   4
# 3200              2000                   3
# 1536              1024                   2
# 3456              2160                   2
# 2880              1864                   2
# 1200              1920                   2
# 3840              2400                   2
# 2560              1664                   2
# 2160              1440                   2
# 2560              1660                   1
# ...

# %%
sns.scatterplot(x=df['resolution_height'], y=df['resolution_width'])
# Out:
# <Axes: xlabel='resolution_height', ylabel='resolution_width'>

# %% [markdown]
# # Models with max Warranty

# %%
model_warranty_year = df.groupby('Model')['year_of_warranty'].max().sort_values(ascending=False).head(30)
model_warranty_year
# Out:
# Model
# HP 250 G8 7M6L7PA Laptop (11th Gen Core i3/ 8GB/ 1TB 256GB SSD/ Win11)                                     No information
# Lenovo IdeaPad D330 82H0001YIN Laptop (Celeron N4020/ 4GB/ 128GB eMMC/ Win10)                              No information
# Dell Inspiron 3501 Laptop (11th Gen Core i5/ 8GB/ 1TB 256GB SSD/ Win10)                                    No information
# HP Zbook Power G4-A 2023 ZHAN 99 Laptop (AMD Ryzen 5 6600H/ 16GB/ 1TB 512GB SSD/ Win11/ 4GB Graph)         No information
# MSI Thin GF63 11UC-1490IN Gaming Laptop (11th Gen Core i5/ 16GB/ 1TB 256GB SSD/ Win11 Home/ 4GB Graph)     No information
# MSI Thin GF63 11UC-1494IN Gaming Laptop (11th Gen Core i7/ 16GB/ 1TB 256GB SSD/ Win11 Home/ 4GB Graph)     No information
# MSI Thin GF63 11UCX-1492IN Gaming Laptop (11th Gen Core i5/ 16GB/ 1TB 256GB SSD/ Win11 Home/ 4GB Graph)    No information
# MSI Thin GF63 12UCX-269IN Gaming Laptop (12th Gen Core i5/ 16GB/ 1TB 256GB SSD/ Win11 Home/ 4GB Graph)     No information
# ...

# %% [markdown]
# # Total Model By Ram Memory

# %%
model_by_ram = df.groupby('ram_memory')['Model'].count().sort_values(ascending=False)
model_by_ram
# Out:
# ram_memory
# 16    522
# 8     402
# 32     36
# 4      25
# 12      3
# 36      2
# 2       1
# Name: Model, dtype: int64

# %%
model_by_ram_sorted = model_by_ram.sort_index()

# %%
plt.figure(figsize=(10,2))
plt.plot(model_by_ram_sorted.index, model_by_ram_sorted.values, marker='o', color='red')
plt.title('Total Models by Ram Memory')  
plt.xlabel('Ram Memory')
plt.ylabel('Total Models')
sns.set_style("whitegrid")
plt.grid(False)
plt.xticks(model_by_ram_sorted.index)
plt.show()

# %% [markdown]
# # Total Model By GPU Brand

# %%
model_by_gpu_brand = df.groupby('gpu_brand')['Model'].count().sort_values(ascending=False)
model_by_gpu_brand
# Out:
# gpu_brand
# intel     462
# nvidia    343
# amd       167
# apple      15
# arm         4
# Name: Model, dtype: int64

# %%
barplot5=sns.barplot(y=model_by_gpu_brand.values, x=model_by_gpu_brand.index, orient='vertical', palette='RdPu')
plt.bar_label(barplot5.containers[0], labels=model_by_gpu_brand.values, label_type='edge')
plt.title('Total Models By GPU Brand')  
plt.xlabel('GPU Brand')
plt.ylabel('Total Models')
sns.set_style("whitegrid")
plt.grid(False)
plt.show()

# %% [markdown]
# # Total Model By GPU Type

# %%
model_by_gpu_type = df.groupby('gpu_type')['Model'].count().sort_values(ascending=False)
model_by_gpu_type
# Out:
# gpu_type
# integrated    616
# dedicated     360
# apple          15
# Name: Model, dtype: int64

# %%
plt.pie(model_by_gpu_type.values, labels=model_by_gpu_type.index, autopct='%1.1f%%', startangle=140)
plt.title('Distribution of Models by GPU Type')
plt.show()

# %%
model_by_resolution = df.groupby(['resolution_width','resolution_height'])['Model'].count().sort_values(ascending=False).head(10)
model_by_resolution
# Out:
# resolution_width  resolution_height
# 1920              1080                 648
#                   1200                 128
# 2560              1600                  64
# 1366              768                   52
# 2880              1800                  29
# 2560              1440                  14
# 1080              1920                   7
# 2880              1620                   6
# 3200              1800                   5
# 3456              2234                   4
# Name: Model, dtype: int64

# %% [markdown]
# # Total Models By Rating(out of 100)

# %%
model_by_rating = df.groupby(['Rating'])['Model'].count().sort_values(ascending=False).head(10)
model_by_rating
# Out:
# Rating
# 58    52
# 64    48
# 60    47
# 62    46
# 67    46
# 57    46
# 70    46
# 59    43
# 71    42
# 65    42
# Name: Model, dtype: int64

# %%
plt.figure(figsize=(10,10))
barplot6=sns.barplot(x=model_by_rating.values, y=model_by_rating.index, orient='horizontal', palette='plasma')
plt.bar_label(barplot6.containers[0], labels=model_by_rating.values, label_type='edge')
plt.title('Total Models By Rating')  
plt.ylabel('Rating')
plt.xlabel('Total Models')
sns.set_style("whitegrid")
plt.grid(False)
plt.show()

# %% [markdown]
# # Total Brands By Average Price

# %%
model_by_avg_price = df.groupby(['brand'])['Price'].mean().sort_values(ascending=False)
model_by_avg_price
# Out:
# brand
# apple        193875.333333
# lg           115284.714286
# dell         101701.132075
# msi           94260.433333
# microsoft     88740.000000
# fujitsu       82890.800000
# gigabyte      80990.000000
# asus          78290.223810
# hp            76005.604878
# samsung       67990.000000
# lenovo        65527.562189
# acer          62847.876404
# honor         49490.000000
# realme        39990.000000
# zebronics     39132.857143
# infinix       38220.769231
# tecno         29990.000000
# wings         29990.000000
# chuwi         28740.000000
# avita         25461.800000
# ultimus       17060.500000
# axl           16490.000000
# walker        15990.000000
# jio           14701.000000
# primebook     13990.000000
# iball          9800.000000
# Name: Price, dtype: float64

# %%
model_by_avg_price_rounded = model_by_avg_price.round(2)

# %%
plt.figure(figsize=(10,10))
barplot7=sns.barplot(x=model_by_avg_price_rounded.values, y=model_by_avg_price_rounded.index, orient='horizontal', palette='plasma')
plt.bar_label(barplot7.containers[0], labels=model_by_avg_price_rounded.values, label_type='edge')
plt.title('Total Brands By Average Price')  
plt.ylabel('Average Price')
plt.xlabel('Total Brands')
plt.xlim(0,220000)
sns.set_style("whitegrid")
plt.grid(False)
plt.show()

# %% [markdown]
# # Price

# %%
sns.distplot(df['Price'])
plt.grid(False)
# Out:
# C:\Users\utkar\AppData\Local\Temp\ipykernel_17804\31553000.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Price'])

# %% [markdown]
# # Display

# %%
plt.figure(figsize=(10,6))
display=sns.countplot(x='display_size', data=df)
for bars in display.containers:
    display.bar_label(bars)
    plt.grid(False)

# %% [markdown]
# # Most Expensive Laptop

# %%
df.groupby(['Model'])['Price'].max().sort_values(ascending=False).head(1)
# Out:
# Model
# Dell Alienware X16 Gaming Laptop (13th Gen Core i9/ 32GB/ 2TB SSD/ Win 11/ 16GB Graph)    454490
# Name: Price, dtype: int64

# %% [markdown]
# # Least Expensive Laptop

# %%
df.groupby(['Model'])['Price'].min().sort_values(ascending=False).tail(1)
# Out:
# Model
# iBall Excelance CompBook Laptop (AQC/ 2GB/ 32GB/Win10)    9800
# Name: Price, dtype: int64

# %% [markdown]
# # Gaming Laptops

# %%
gaming_laptops = df[df['Model'].str.contains('Gaming')]
gaming_laptops
# Out:
#       brand                                              Model   Price  \
# index
# 3        hp  HP Victus 15-fb0157AX Gaming Laptop (AMD Ryzen...   51100
# 8      asus  Asus TUF Gaming F15 FX506HF-HN024W Gaming Lapt...   49990
# 13      msi  MSI Thin GF63 12UC-846IN Gaming Laptop (12th G...   52990
# 16       hp  HP Omen 16-wf1025TX Gaming Laptop (14th Gen Co...  153990
# 18     asus  Asus TUF Gaming F15 FX506HE-HN385WS Gaming Lap...   75990
# ...     ...                                                ...     ...
# 985    acer  Acer Nitro 5 AN515-47 NH.QL3SI.001 Gaming Lapt...   68999
# 988    asus  Asus ROG Strix SCAR 16 2023 G634JZ-N4062WS Gam...  279990
# 993     msi  MSI Katana 15 B13VFK-296IN Gaming Laptop (13th...  119990
# 997    acer  Acer Nitro 5 AN515-47 NH.QL3SI.003 Gaming Lapt...   75500
# 999     msi  MSI Thin GF63 12VE-070IN Gaming Laptop (12th G...   91990
#
#        Rating processor_brand processor_tier  num_cores  num_threads  \
# index
# ...

# %% [markdown]
# # Laptop for normal task, normal usage under budget

# %%
df[(df['brand'].isin(['acer', 'apple', 'lenevo', 'asus', 'dell'])) & (df['primary_storage_capacity'] == 1024) & (df['ram_memory'].isin([16,32])) & (df['OS'] == 'windows') & (df['Rating'] > 60) & (df['Price'] > 30000) & (df['Price'] < 45000)]
# Out:
#       brand                                              Model  Price  Rating  \
# index
# 355    acer  Acer Aspire Lite AL15-41 Laptop (AMD Ryzen 5 5...  39800      62
#
#       processor_brand processor_tier  num_cores  num_threads  ram_memory  \
# index
# 355               amd        ryzen 5          6           12          16
#
#       primary_storage_type  ...  secondary_storage_type  \
# index                       ...
# 355                    SSD  ...    No secondary storage
#
#       secondary_storage_capacity  gpu_brand    gpu_type is_touch_screen  \
# index
# 355                            0        amd  integrated           False
#
#        display_size  resolution_width  resolution_height       OS  \
# index
# 355            15.6              1920               1080  windows
#
#       year_of_warranty
# index
# 355                  1
#
# [1 rows x 21 columns]

# %% [markdown]
# # Insights

# %% [markdown]
# ASUS is offering highest number of models
#
#  Windows is the common Operating System
#
#  Most Process Brand is by Intel and Process Tier is mostly by core i5, followed by core i7
#
#  Primary storage is SSD, whereas secondary storage is not present in 98% of the laptops
#
#  Primary storage capacity 512 is available in most laptops
#
#  Touch Screen is not offered in most of of laptops, only in 8.8% laptops
#
#  Laptop which is most expensive is from DELL exclusively made for gaming purpose and if talk about average  pricing Apple laptops are most expensive
#
#  Average warranty of laptops are 1 year including most expensive laptop and mac laptops, whereas Lenevo is  providing warranty for 3 years, mostly having windows OS
#
#  Ram memory of most the laptops is 16 GB, followed by 8 GB
#
#  Common Resolution(height) is 1080 ,  Resolution(width) is 1920
#
#  GPU brand mostly by Intel followed by nvidia
#
#  Dell Alienware m16 Gaming Laptop (AMD Ryzen 9 7845HX/ 32GB/ 2TB SSD/ Win 11/ 12GB Graph) might be the best laptop as it has window OS, 32 GB Ram with primary storage capacity of 2048 but its name suggests it is best suited for gaming
#
#  For budget friendly, normal tasks with primary capacity of 1024, 16 GB, window OS & rating 62 is Acer Aspire Lite AL15-41 Laptop (AMD Ryzen 5 5500U/ 16GB/ 1TB SSD/ Win11)
