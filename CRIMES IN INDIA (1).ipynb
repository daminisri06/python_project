# %%
import pandas as pd
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Crimes_in_india.csv')
df
# Out:
#               STATES        STATE/UT       DISTRICT  YEAR  MURDER  \
# 0     ANDHRA PRADESH  ANDHRA PRADESH       ADILABAD  2001     101
# 1     ANDHRA PRADESH  ANDHRA PRADESH      ANANTAPUR  2001     151
# 2     ANDHRA PRADESH  ANDHRA PRADESH       CHITTOOR  2001     101
# 3     ANDHRA PRADESH  ANDHRA PRADESH       CUDDAPAH  2001      80
# 4     ANDHRA PRADESH  ANDHRA PRADESH  EAST GODAVARI  2001      82
# ...              ...             ...            ...   ...     ...
# 9835     LAKSHADWEEP     Lakshadweep    LAKSHADWEEP  2013       0
# 9836     LAKSHADWEEP     Lakshadweep       ZZ TOTAL  2013       0
# 9837      PUDUCHERRY      Puducherry       KARAIKAL  2013       6
# 9838      PUDUCHERRY      Puducherry     PUDUCHERRY  2013      25
# 9839      PUDUCHERRY      Puducherry       ZZ TOTAL  2013      31
#
#       ATTEMPT TO MURDER  CULPABLE HOMICIDE NOT AMOUNTING TO MURDER  RAPE  \
# 0                    60                                         17    50
# ...

# %%
df.dtypes
# Out:
# STATES                                                 object
# STATE/UT                                               object
# DISTRICT                                               object
# YEAR                                                    int64
# MURDER                                                  int64
# ATTEMPT TO MURDER                                       int64
# CULPABLE HOMICIDE NOT AMOUNTING TO MURDER               int64
# RAPE                                                    int64
# CUSTODIAL RAPE                                          int64
# OTHER RAPE                                              int64
# KIDNAPPING & ABDUCTION                                  int64
# KIDNAPPING AND ABDUCTION OF WOMEN AND GIRLS             int64
# KIDNAPPING AND ABDUCTION OF OTHERS                      int64
# DACOITY                                                 int64
# PREPARATION AND ASSEMBLY FOR DACOITY                    int64
# ...

# %%
df.isnull().sum()
# Out:
# STATES                                                 0
# STATE/UT                                               0
# DISTRICT                                               0
# YEAR                                                   0
# MURDER                                                 0
# ATTEMPT TO MURDER                                      0
# CULPABLE HOMICIDE NOT AMOUNTING TO MURDER              0
# RAPE                                                   0
# CUSTODIAL RAPE                                         0
# OTHER RAPE                                             0
# KIDNAPPING & ABDUCTION                                 0
# KIDNAPPING AND ABDUCTION OF WOMEN AND GIRLS            0
# KIDNAPPING AND ABDUCTION OF OTHERS                     0
# DACOITY                                                0
# PREPARATION AND ASSEMBLY FOR DACOITY                   0
# ROBBERY                                                0
# ...

# %%
df.columns
# Out:
# Index(['STATES', 'STATE/UT', 'DISTRICT', 'YEAR', 'MURDER', 'ATTEMPT TO MURDER',
#        'CULPABLE HOMICIDE NOT AMOUNTING TO MURDER', 'RAPE', 'CUSTODIAL RAPE',
#        'OTHER RAPE', 'KIDNAPPING & ABDUCTION',
#        'KIDNAPPING AND ABDUCTION OF WOMEN AND GIRLS',
#        'KIDNAPPING AND ABDUCTION OF OTHERS', 'DACOITY',
#        'PREPARATION AND ASSEMBLY FOR DACOITY', 'ROBBERY', 'BURGLARY', 'THEFT',
#        'AUTO THEFT', 'OTHER THEFT', 'RIOTS', 'CRIMINAL BREACH OF TRUST',
#        'CHEATING', 'COUNTERFIETING', 'ARSON', 'HURT/GREVIOUS HURT',
#        'DOWRY DEATHS', 'ASSAULT ON WOMEN WITH INTENT TO OUTRAGE HER MODESTY',
#        'INSULT TO MODESTY OF WOMEN', 'CRUELTY BY HUSBAND OR HIS RELATIVES',
#        'IMPORTATION OF GIRLS FROM FOREIGN COUNTRIES',
#        'CAUSING DEATH BY NEGLIGENCE', 'OTHER IPC CRIMES', 'TOTAL IPC CRIMES',
#        'TOTAL '],
#       dtype='object')

# %%
df.shape
# Out:
# (9840, 35)

# %%
df.describe()
# Out:
#               YEAR       MURDER  ATTEMPT TO MURDER  \
# count  9840.000000  9840.000000        9840.000000
# mean   2007.161890    88.565854          78.738618
# std       3.755581   325.417692         306.650391
# min    2001.000000     0.000000           0.000000
# 25%    2004.000000    18.000000          10.000000
# 50%    2007.000000    37.000000          28.000000
# 75%    2010.000000    66.000000          57.000000
# max    2013.000000  7601.000000        7964.000000
#
#        CULPABLE HOMICIDE NOT AMOUNTING TO MURDER         RAPE  CUSTODIAL RAPE  \
# count                                9840.000000  9840.000000     9840.000000
# mean                                    9.754878    55.456098        0.005488
# std                                    58.733349   201.690457        0.111218
# min                                     0.000000     0.000000        0.000000
# 25%                                     0.000000     8.000000        0.000000
# ...

# %% [markdown]
# # Total Crimes in each YEAR

# %%
total_crime_year = df.groupby('YEAR')['TOTAL '].sum().sort_values(ascending=False)
total_crime_year
# Out:
# YEAR
# 2013    11534468
# 2012    10368596
# 2011    10121640
# 2010     9681172
# 2009     9244284
# 2008     9110494
# 2007     8625374
# 2006     8148558
# 2004     7957250
# 2005     7919012
# 2002     7692690
# 2001     7659962
# 2003     7426632
# Name: TOTAL , dtype: int64

# %%
total_crime_year_sorted = total_crime_year.sort_index()

# %%
plt.figure(figsize=(10,2))
plt.plot(total_crime_year_sorted .index, total_crime_year_sorted.values, marker='o', color='red')
plt.title('Total Number Of Crimes In Each Year')  
plt.xlabel('Year')
plt.ylabel('Total Crimes')
sns.set_style("whitegrid")
plt.grid(False)
plt.xticks(total_crime_year_sorted.index)
plt.show()

# %% [markdown]
# # Total Crimes in each STATE

# %%
df.groupby('STATES')['TOTAL '].sum().sort_values(ascending=False)
# Out:
# STATES
# MAHARASHTRA                                 11327818
# MADHYA PRADESH                              11254170
# ANDHRA PRADESH                               9661372
# TAMIL NADU                                   9499154
# UTTAR PRADESH                                9231182
# RAJASTHAN                                    8841956
# KARNATAKA                                    6946578
# GUJARAT                                      6675666
# KERALA                                       6611658
# BIHAR                                        6518666
# WEST BENGAL                                  5688188
# DELHI                                        3455646
# ODISHA                                       3115140
# ASSAM                                        3033490
# HARYANA                                      3007250
# CHHATTISGARH                                 2645308
# JHARKHAND                                    2078778
# PUNJAB                                       1824448
# ...

# %%
total_crime_states = df.groupby('STATES')['TOTAL '].sum().sort_values(ascending=False).head(10)
total_crime_states
# Out:
# STATES
# MAHARASHTRA       11327818
# MADHYA PRADESH    11254170
# ANDHRA PRADESH     9661372
# TAMIL NADU         9499154
# UTTAR PRADESH      9231182
# RAJASTHAN          8841956
# KARNATAKA          6946578
# GUJARAT            6675666
# KERALA             6611658
# BIHAR              6518666
# Name: TOTAL , dtype: int64

# %%
sns.barplot(x=total_crime_states.values, y=total_crime_states.index, orient='horizontal', palette='rocket')
plt.title('Total Number Of Crimes In Each State')  
plt.ylabel('States')
plt.xlabel('Total Crimes')
sns.set_style("whitegrid")
plt.grid(False)
plt.show()

# %% [markdown]
# # Total Murders in each State

# %%
df.groupby('STATES')['MURDER'].sum().sort_values(ascending=False)
# Out:
# STATES
# UTTAR PRADESH                               140980
# BIHAR                                        89372
# MAHARASHTRA                                  70558
# ANDHRA PRADESH                               68480
# MADHYA PRADESH                               61022
# WEST BENGAL                                  46640
# TAMIL NADU                                   44126
# KARNATAKA                                    43076
# JHARKHAND                                    41380
# RAJASTHAN                                    34834
# ASSAM                                        33572
# ODISHA                                       31814
# GUJARAT                                      29786
# CHHATTISGARH                                 26010
# HARYANA                                      22906
# PUNJAB                                       20408
# DELHI                                        13444
# JAMMU & KASHMIR                              12908
# ...

# %%
total_murder_states = df.groupby('STATES')['MURDER'].sum().sort_values(ascending=False).head(10)
total_murder_states
# Out:
# STATES
# UTTAR PRADESH     140980
# BIHAR              89372
# MAHARASHTRA        70558
# ANDHRA PRADESH     68480
# MADHYA PRADESH     61022
# WEST BENGAL        46640
# TAMIL NADU         44126
# KARNATAKA          43076
# JHARKHAND          41380
# RAJASTHAN          34834
# Name: MURDER, dtype: int64

# %%
sns.barplot(y=total_murder_states .values, x=total_murder_states .index, orient='vertical', palette='plasma')
sns.set_style("whitegrid")
plt.grid(False)
plt.title('Total Number Of Murders In Each State')  
plt.xlabel('States')
plt.xticks(rotation=45)
plt.ylabel('Total Murders')
plt.show()

# %% [markdown]
# # Total kidnapping in each State

# %%
df['TOTAL KIDNAPPING & ABDUCTION'] = df['KIDNAPPING & ABDUCTION'] + df['KIDNAPPING AND ABDUCTION OF WOMEN AND GIRLS'] + df['KIDNAPPING AND ABDUCTION OF OTHERS']

# %%
df
# Out:
#               STATES        STATE/UT       DISTRICT  YEAR  MURDER  \
# 0     ANDHRA PRADESH  ANDHRA PRADESH       ADILABAD  2001     101
# 1     ANDHRA PRADESH  ANDHRA PRADESH      ANANTAPUR  2001     151
# 2     ANDHRA PRADESH  ANDHRA PRADESH       CHITTOOR  2001     101
# 3     ANDHRA PRADESH  ANDHRA PRADESH       CUDDAPAH  2001      80
# 4     ANDHRA PRADESH  ANDHRA PRADESH  EAST GODAVARI  2001      82
# ...              ...             ...            ...   ...     ...
# 9835     LAKSHADWEEP     Lakshadweep    LAKSHADWEEP  2013       0
# 9836     LAKSHADWEEP     Lakshadweep       ZZ TOTAL  2013       0
# 9837      PUDUCHERRY      Puducherry       KARAIKAL  2013       6
# 9838      PUDUCHERRY      Puducherry     PUDUCHERRY  2013      25
# 9839      PUDUCHERRY      Puducherry       ZZ TOTAL  2013      31
#
#       ATTEMPT TO MURDER  CULPABLE HOMICIDE NOT AMOUNTING TO MURDER  RAPE  \
# 0                    60                                         17    50
# ...

# %%
df.groupby('STATES')['TOTAL KIDNAPPING & ABDUCTION'].sum().sort_values(ascending=False)
# Out:
# STATES
# UTTAR PRADESH                               281796
# BIHAR                                       171160
# RAJASTHAN                                   142852
# ASSAM                                       130960
# DELHI                                       125508
# WEST BENGAL                                 122288
# ANDHRA PRADESH                               93432
# GUJARAT                                      71648
# MAHARASHTRA                                  70964
# TAMIL NADU                                   68328
# MADHYA PRADESH                               61248
# ODISHA                                       48396
# KARNATAKA                                    47460
# HARYANA                                      45712
# JAMMU & KASHMIR                              42592
# JHARKHAND                                    38988
# PUNJAB                                       35572
# CHHATTISGARH                                 22320
# ...

# %%
total_kid = df.groupby('STATES')['TOTAL KIDNAPPING & ABDUCTION'].sum().sort_values(ascending=False).head(5)
total_kid
# Out:
# STATES
# UTTAR PRADESH    281796
# BIHAR            171160
# RAJASTHAN        142852
# ASSAM            130960
# DELHI            125508
# Name: TOTAL KIDNAPPING & ABDUCTION, dtype: int64

# %%
plt.pie(total_kid, labels=total_kid.index, autopct='%1.1f%%', startangle=140)
plt.title('Top 5 States by Total Kidnapping & Abduction')
plt.show()

# %% [markdown]
# # Total Theft cases in each State

# %%
df['TOTAL THEFT'] = df['AUTO THEFT'] + df['OTHER THEFT'] + df['THEFT']

# %%
total_theft = df.groupby('STATES')['TOTAL THEFT'].sum().sort_values(ascending=False)
total_theft
# Out:
# STATES
# MAHARASHTRA                                 2437908
# UTTAR PRADESH                               1415984
# ANDHRA PRADESH                              1272888
# MADHYA PRADESH                              1155620
# RAJASTHAN                                   1047608
# DELHI                                       1046680
# GUJARAT                                      914080
# KARNATAKA                                    878864
# WEST BENGAL                                  853488
# TAMIL NADU                                   788440
# BIHAR                                        699180
# HARYANA                                      600056
# ASSAM                                        383960
# ODISHA                                       371524
# JHARKHAND                                    312644
# CHHATTISGARH                                 272248
# KERALA                                       265728
# PUNJAB                                       221552
# ...

# %%
plt.figure(figsize=(8, 8))
sns.barplot(x=total_theft.values, y=total_theft.index, orient='horizontal', palette='YlOrBr')
plt.title('Total Number Of Theft Cases In Each State')  
plt.ylabel('States')
plt.xlabel('Total Theft')
sns.set_style("whitegrid")
plt.grid(False)
plt.show()

# %% [markdown]
# # Total Rape cases in each State

# %%
df['TOTAL RAPES'] = df['RAPE'] + df['CUSTODIAL RAPE'] + df['OTHER RAPE']

# %%
total_rapes = df.groupby('STATES')['TOTAL RAPES'].sum().sort_values(ascending=False)
total_rapes
# Out:
# STATES
# MADHYA PRADESH                              161688
# WEST BENGAL                                  89888
# UTTAR PRADESH                                88432
# MAHARASHTRA                                  84196
# RAJASTHAN                                    76332
# ASSAM                                        72460
# ANDHRA PRADESH                               60456
# BIHAR                                        57008
# ODISHA                                       53048
# CHHATTISGARH                                 52872
# JHARKHAND                                    41452
# KERALA                                       34672
# DELHI                                        32240
# TAMIL NADU                                   31500
# HARYANA                                      29524
# PUNJAB                                       25388
# KARNATAKA                                    24816
# GUJARAT                                      19924
# ...

# %%
plt.figure(figsize=(8, 8))
sns.barplot(x=total_rapes.values, y=total_rapes.index, orient='horizontal', palette='viridis')
plt.title('Total Number Of Theft Cases In Each State')  
plt.ylabel('States')
plt.xlabel('Total Theft')
sns.set_style("whitegrid")
plt.grid(False)
plt.show()

# %% [markdown]
# # Total dowry deaths cases in each State

# %%
df.groupby('STATES')['DOWRY DEATHS'].sum().sort_values(ascending=False)
# Out:
# STATES
# UTTAR PRADESH                               52318
# BIHAR                                       29460
# MADHYA PRADESH                              19624
# ANDHRA PRADESH                              13414
# WEST BENGAL                                 11306
# RAJASTHAN                                   11038
# ODISHA                                       9900
# MAHARASHTRA                                  9138
# JHARKHAND                                    7196
# HARYANA                                      6786
# KARNATAKA                                    6390
# TAMIL NADU                                   4870
# DELHI                                        3452
# PUNJAB                                       3344
# ASSAM                                        2892
# CHHATTISGARH                                 2502
# UTTARAKHAND                                  1898
# GUJARAT                                      1062
# TRIPURA                                       686
# ...

# %%
total_dowry = df.groupby('STATES')['DOWRY DEATHS'].sum().sort_values(ascending=False).head(10)
total_dowry
# Out:
# STATES
# UTTAR PRADESH     52318
# BIHAR             29460
# MADHYA PRADESH    19624
# ANDHRA PRADESH    13414
# WEST BENGAL       11306
# RAJASTHAN         11038
# ODISHA             9900
# MAHARASHTRA        9138
# JHARKHAND          7196
# HARYANA            6786
# Name: DOWRY DEATHS, dtype: int64

# %%
plt.figure(figsize=(8, 8))
sns.barplot(y=total_dowry.values, x=total_dowry.index, orient='vertical', palette='RdPu')
plt.title('Total Number Of Dowry Deaths Cases In Each State')  
plt.xlabel('States')
plt.ylabel('Dowry Deaths')
sns.set_style("whitegrid")
plt.xticks(rotation=45)
plt.grid(False)
plt.show()

# %% [markdown]
# # Total burglary cases in each State

# %%
total_burglary = df.groupby('STATES')['BURGLARY'].sum().sort_values(ascending=False)
total_burglary
# Out:
# STATES
# MAHARASHTRA                                 407890
# MADHYA PRADESH                              296706
# ANDHRA PRADESH                              214312
# KARNATAKA                                   158602
# UTTAR PRADESH                               144540
# RAJASTHAN                                   142102
# GUJARAT                                     131338
# TAMIL NADU                                  116928
# HARYANA                                     105250
# KERALA                                       98600
# CHHATTISGARH                                 96366
# BIHAR                                        88956
# ODISHA                                       80504
# ASSAM                                        78086
# PUNJAB                                       60656
# DELHI                                        52780
# JAMMU & KASHMIR                              36874
# JHARKHAND                                    36038
# ...

# %%
plt.figure(figsize=(8, 8))
sns.barplot(x=total_burglary.values, y=total_burglary.index, orient='horizontal', palette='Greens_d')
plt.title('Total Number Of Burglary Cases In Each State')  
plt.ylabel('States')
plt.xlabel('Total Burglary')
sns.set_style("whitegrid")
plt.grid(False)
plt.show()

# %% [markdown]
# # Total hurt greviously cases in each State

# %%
df.groupby('STATES')['HURT/GREVIOUS HURT'].sum().sort_values(ascending=False)
# Out:
# STATES
# ANDHRA PRADESH                              1214106
# MADHYA PRADESH                               895666
# MAHARASHTRA                                  769112
# TAMIL NADU                                   603314
# RAJASTHAN                                    572216
# KARNATAKA                                    544900
# KERALA                                       505700
# BIHAR                                        449882
# UTTAR PRADESH                                304296
# GUJARAT                                      290270
# WEST BENGAL                                  224622
# CHHATTISGARH                                 191144
# ODISHA                                       173008
# ASSAM                                        154708
# PUNJAB                                       121672
# HARYANA                                      108850
# JHARKHAND                                     92418
# DELHI                                         47956
# ...

# %%
total_hurt = df.groupby('STATES')['HURT/GREVIOUS HURT'].sum().sort_values(ascending=False).head(10)
total_hurt
# Out:
# STATES
# ANDHRA PRADESH    1214106
# MADHYA PRADESH     895666
# MAHARASHTRA        769112
# TAMIL NADU         603314
# RAJASTHAN          572216
# KARNATAKA          544900
# KERALA             505700
# BIHAR              449882
# UTTAR PRADESH      304296
# GUJARAT            290270
# Name: HURT/GREVIOUS HURT, dtype: int64

# %%
plt.figure(figsize=(8, 8))
sns.barplot(y=total_hurt.values, x=total_hurt.index, orient='vertical', palette='Blues_d')
plt.title('Total Number Of Greviously Hurt Cases In Each State')  
plt.xlabel('States')
plt.ylabel('Greviously Hurt')
sns.set_style("whitegrid")
plt.xticks(rotation=45)
plt.grid(False)
plt.show()

# %% [markdown]
# # Crimes majorily involving women in each state

# %%
df['CRIMES_MAJORILY_INVOLVING_WOMEN'] = df['RAPE']+df['KIDNAPPING AND ABDUCTION OF WOMEN AND GIRLS']+df['DOWRY DEATHS']+df['ASSAULT ON WOMEN WITH INTENT TO OUTRAGE HER MODESTY']+df['INSULT TO MODESTY OF WOMEN']+df['CRUELTY BY HUSBAND OR HIS RELATIVES']+df['IMPORTATION OF GIRLS FROM FOREIGN COUNTRIES']

# %%
total_crimes_women = df.groupby('STATES')['CRIMES_MAJORILY_INVOLVING_WOMEN'].sum().sort_values(ascending=False)
total_crimes_women
# Out:
# STATES
# ANDHRA PRADESH                              544444
# UTTAR PRADESH                               511064
# WEST BENGAL                                 465100
# MADHYA PRADESH                              411114
# RAJASTHAN                                   409166
# MAHARASHTRA                                 378690
# ASSAM                                       221784
# KERALA                                      203054
# GUJARAT                                     199172
# BIHAR                                       183270
# ODISHA                                      176012
# KARNATAKA                                   156056
# TAMIL NADU                                  151784
# HARYANA                                     130610
# DELHI                                       121884
# CHHATTISGARH                                106142
# JHARKHAND                                    71166
# PUNJAB                                       68106
# ...

# %%
plt.figure(figsize=(8, 8))
sns.barplot(x=total_crimes_women.values, y=total_crimes_women.index, orient='horizontal', palette='BrBG')
plt.title('Total Number Of Crimes majorily involving women In Each State')  
plt.ylabel('States')
plt.xlabel('Total Crime')
sns.set_style("whitegrid")
plt.grid(False)
plt.show()

# %% [markdown]
# # Insights
# Total Cases Registered 115M, constant increase from 2003 to 2013 going from 7.4M to 11.5M
#
# Maharashtra has observed highest number of crimes
#
# Out of total number of crimes Murder cases are 775k mostly committed in Uttar Pradesh
#
# Deaths by Dowry also observed the most in Uttar Pradesh
#
# Robbery cases registered mostly in Maharashtra followed by Uttar Pradesh
#
# Burglary cases registered mostly in Maharashtra followed by Madhya Pradesh
#
# West Bengal was highest in number of Cheating Cases
#
# Rape cases happened in Madhya Pradesh followed by Uttar Pradesh, which also topped in Kidnapping & Abduction Cases
#
# Theft cases committed most in Maharashtra followed by Uttar Pradesh
#
# Cheating cases registered mostly in Rajasthan followed by Andhra Pradesh then Uttar Pradesh
#
# Crimes against women in totality has been observed by West Bengal with Uttar Pradesh making in top 5
#
# If take a look at overall data Maharashtra has highest cases but Uttar Pradesh is also making headline in every category.
